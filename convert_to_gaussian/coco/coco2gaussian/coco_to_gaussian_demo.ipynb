# %%
# %matplotlib inline
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (8.0, 10.0)
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# dataDir='/dl/data/coco'
# dataType='val2017'
# annFile='{}/annotations/instances_{}.json'.format(dataDir,dataType)
annFile='/media/pesong/e/dl_gaussian/model/Detectron.pytorch/lib/datasets/convert_to_gaussian/coco/coco2gaussian/Annotations_.json'

# initialize COCO api for instance annotations
coco=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=1.85s)
# creating index...
# index created!

# %%
# display COCO categories and supercategories
cats = coco.loadCats(coco.getCatIds())
nms=[cat['name'] for cat in cats]
print('COCO categories: \n{}\n'.format(' '.join(nms)))

nms = set([cat['supercategory'] for cat in cats])
print('COCO supercategories: \n{}'.format(' '.join(nms)))
# Out:
# COCO categories:
# wall building motorcycle bicycle person robot rider bus car truck pole traffic light dustbin traffic sign billboard others potted plant ladder pack chair carpet slops garbage table face lane markings road sidewalk pavement sky vegetation road_pile traffic_cone fence
#
# COCO supercategories:
# construction target object roadside object movable object road obstacles nature flat others

# %%
# get all images containing given categories, select one at random
catIds = coco.getCatIds(catNms=['vegetation'])
print(catIds)
imgIds = coco.getImgIds(catIds=catIds)
# imgIds = coco.getImgIds(imgIds = [299553])
img = coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]
print(str(img['id']))

# load and display image
# I = io.imread('%s/images/%s/%s'%(dataDir,dataType,img['file_name']))
# use url to load image
I = io.imread(img['coco_url'])
plt.axis('off')
plt.imshow(I)
plt.show()
# Out:
# [62]
# 308391

# %%
# load and display instance annotations
plt.imshow(I); plt.axis('off')
annIds = coco.getAnnIds(imgIds=img['id'],catIds=catIds)
anns = coco.loadAnns(annIds)
print([ann['category_id'] for ann in anns])
# print([ann['bbox'] for ann in anns ])

coco.showAnns(anns, True)
# Out:
# [62]

# %%
# initialize COCO api for person keypoints annotations
annFile = '{}/annotations/person_keypoints_{}.json'.format(dataDir,dataType)
coco_kps=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.90s)
# creating index...
# index created!

# %%
# load and display keypoints annotations
plt.imshow(I); plt.axis('off')
ax = plt.gca()
annIds = coco_kps.getAnnIds(imgIds=img['id'], catIds=catIds, iscrowd=None)
anns = coco_kps.loadAnns(annIds)
coco_kps.showAnns(anns)
# Out:
# 0

# %%
# initialize COCO api for caption annotations
annFile = '{}/annotations/captions_{}.json'.format(dataDir,dataType)
coco_caps=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!

# %%
# load and display caption annotations
annIds = coco_caps.getAnnIds(imgIds=img['id']);
anns = coco_caps.loadAnns(annIds)
coco_caps.showAnns(anns)
plt.imshow(I); plt.axis('off'); plt.show()
# Out:
# A large and wide street covered in lots of traffic lights.
# cars are stopped at a traffic light on a highway
# Traffic is stopped at a red stop light.
# A traffic light and intersection with cars traveling in both directions on the street.
# A number of red and green traffic lights on a wide highway.
